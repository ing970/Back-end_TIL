# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/corazzon/finance-data-analysis/blob/main/6.2%20%EB%B3%80%EB%8F%99%EC%84%B1%20%EC%A7%80%ED%91%9C%20%EB%B3%BC%EB%A6%B0%EC%A0%80%20%EB%B0%B4%EB%93%9C-output.ipynb)
#
#
# ## 볼린저 밴드
#
# 볼린저 밴드(Bollinger Bands)는 1980년대 존 볼린저가 개발하고 2011년 상표권 취득한 주가 기술적 분석 도구이다. 트레이딩 밴드 개념에서 발전된 볼린저 밴드와 상대지표 그리고 대역폭은 이전 거래와의 상대적 가격의 높음과 낮음을 판단하는 데 사용된다. 볼린저 밴드는 켈트너 채널과 비슷한 변동성 지표이다. 볼린저 밴드는 주가가 이동평균선 중심으로 표준편차 범위 안에서 움직인다는 전제로 개발되었다.
#
#
# 볼린저 밴드는 다음과 같이 구성된다.
# * N기간 동안의 이동평균(MA)
# * 이동평균 위의 K배 표준편차 상위 밴드
# * 이동평균 아래의 K배 표준편차 하위 밴드
#
# 일반적으로 N과 K의 값은 20과 2이다. 평균값의 기본 선택의 단순 이동 평균이지만, 필요에 따라 다른 종류의 평균값을 쓸 수 있다. 지수 이동 평균(Exponential moving averages)은 일반적인 대안이다. 대개 중간 밴드와 표준 편차의 계산을 위해 같은 기간을 사용한다.
#
#
#
# * 출처 : [볼린저 밴드 - 위키백과, 우리 모두의 백과사전](https://ko.wikipedia.org/wiki/%EB%B3%BC%EB%A6%B0%EC%A0%80_%EB%B0%B4%EB%93%9C)
#
# https://estiate.tistory.com/entry/%EC%A3%BC%EC%8B%9D-%EC%B4%88%EB%B3%B4%EC%9E%90%EB%A5%BC-%EC%9C%84%ED%95%9C-%EB%B3%BC%EB%A6%B0%EC%A0%80%EB%B0%B4%EB%93%9C-%ED%95%B4%EC%84%9D%EA%B3%BC-%EC%8B%A4%EC%A0%84-%EC%A0%81%EC%9A%A9-%EB%B0%A9%EB%B2%95
#
# ## 라이브러리 로드

# %%
# 데이터 분석을 위해 pandas, numpy, 시각화를 위해 matplotlib 불러오기
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pymysql.cursors
import re

# %%
# 그래프 스타일 설정
plt.style.use("seaborn")
# Out:
# /var/folders/nc/lry6d8ws417_mblykm_8wpc40000gn/T/ipykernel_11386/4282763211.py:2: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use("seaborn")

# %% [markdown]
# ## 개별종목 일별시세 가져오기

# %%
# 데이터베이스 연결
connection = pymysql.connect(host='localhost',   #데이터베이스 아이피
                             user='USER_SQLSTK',  #데이터베이스 사용자
                             password='Aa664303535!!', #데이터베이스 암호
                             database='DB_SQLSTK', #데이터베이스 이름
                             charset='utf8',       # 언어 설정 
                             cursorclass=pymysql.cursors.DictCursor # 조회결과를 dictionary로 리턴
                             )

# %%
connection

# %%
cursor = connection.cursor()

# %%
cursor

# %%
#실행할 SQL
# 2019년 1월 1일 ~ 2020년 12월 31일 삼성전자의 종가 조회
sql = """
      SELECT T1.STK_CD,T1.DT, T1.C_PRC
      FROM  HISTORY_DT T1
      WHERE T1.STK_CD = '019170'
      AND T1.DT >= str_to_date('20190101','%Y%m%d')
      AND T1.DT <= str_to_date('20201231','%Y%m%d')
"""

# %%
# SQL 쿼리를 실행할 준비를 함
cursor.execute(sql)
# Out:
# 490

# %%
# SQL 쿼리를 실행하고 결과를 result에 저장
result = cursor.fetchall()

# %%
# SQL 쿼리 실행 결과 출력
result
# Out:
# [{'STK_CD': '019170',
#   'DT': datetime.date(2019, 1, 2),
#   'C_PRC': Decimal('6260.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 1, 3),
#   'C_PRC': Decimal('6170.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 1, 4),
#   'C_PRC': Decimal('6840.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 1, 7),
#   'C_PRC': Decimal('7410.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 1, 8),
#   'C_PRC': Decimal('7200.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 1, 9),
#   'C_PRC': Decimal('7180.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 1, 10),
#   'C_PRC': Decimal('7110.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 1, 11),
#   'C_PRC': Decimal('6960.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 1, 14),
#   'C_PRC': Decimal('7020.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 1, 15),
#   'C_PRC': Decimal('7130.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 1, 16),
#   'C_PRC': Decimal('6930.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 1, 17),
#   'C_PRC': Decimal('6740.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 1, 18),
#   'C_PRC': Decimal('7040.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 1, 21),
#   'C_PRC': Decimal('7030.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 1, 22),
#   'C_PRC': Decimal('7210.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 1, 23),
#   'C_PRC': Decimal('7200.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 1, 24),
#   'C_PRC': Decimal('7320.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 1, 25),
#   'C_PRC': Decimal('7180.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 1, 28),
#   'C_PRC': Decimal('7390.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 1, 29),
#   'C_PRC': Decimal('7240.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 1, 30),
#   'C_PRC': Decimal('7090.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 1, 31),
#   'C_PRC': Decimal('7250.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 2, 1),
#   'C_PRC': Decimal('7160.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 2, 7),
#   'C_PRC': Decimal('7520.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 2, 8),
#   'C_PRC': Decimal('7690.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 2, 11),
#   'C_PRC': Decimal('8010.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 2, 12),
#   'C_PRC': Decimal('8050.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 2, 13),
#   'C_PRC': Decimal('8250.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 2, 14),
#   'C_PRC': Decimal('8180.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 2, 15),
#   'C_PRC': Decimal('8060.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 2, 18),
#   'C_PRC': Decimal('8340.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 2, 19),
#   'C_PRC': Decimal('8220.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 2, 20),
#   'C_PRC': Decimal('8070.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 2, 21),
#   'C_PRC': Decimal('8040.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 2, 22),
#   'C_PRC': Decimal('8100.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 2, 25),
#   'C_PRC': Decimal('8030.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 2, 26),
#   'C_PRC': Decimal('8010.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 2, 27),
#   'C_PRC': Decimal('8200.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 2, 28),
#   'C_PRC': Decimal('7920.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 3, 4),
#   'C_PRC': Decimal('8630.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 3, 5),
#   'C_PRC': Decimal('8470.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 3, 6),
#   'C_PRC': Decimal('8320.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 3, 7),
#   'C_PRC': Decimal('8190.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 3, 8),
#   'C_PRC': Decimal('8230.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 3, 11),
#   'C_PRC': Decimal('8230.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 3, 12),
#   'C_PRC': Decimal('8180.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 3, 13),
#   'C_PRC': Decimal('8460.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 3, 14),
#   'C_PRC': Decimal('8400.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 3, 15),
#   'C_PRC': Decimal('8090.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 3, 18),
#   'C_PRC': Decimal('7950.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 3, 19),
#   'C_PRC': Decimal('7830.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 3, 20),
#   'C_PRC': Decimal('7950.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 3, 21),
#   'C_PRC': Decimal('7820.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 3, 22),
#   'C_PRC': Decimal('7760.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 3, 25),
#   'C_PRC': Decimal('7650.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 3, 26),
#   'C_PRC': Decimal('7650.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 3, 27),
#   'C_PRC': Decimal('7430.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 3, 28),
#   'C_PRC': Decimal('7190.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 3, 29),
#   'C_PRC': Decimal('7330.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 4, 1),
#   'C_PRC': Decimal('7740.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 4, 2),
#   'C_PRC': Decimal('7520.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 4, 3),
#   'C_PRC': Decimal('7670.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 4, 4),
#   'C_PRC': Decimal('7650.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 4, 5),
#   'C_PRC': Decimal('7750.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 4, 8),
#   'C_PRC': Decimal('7750.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 4, 9),
#   'C_PRC': Decimal('7700.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 4, 10),
#   'C_PRC': Decimal('8070.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 4, 11),
#   'C_PRC': Decimal('7980.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 4, 12),
#   'C_PRC': Decimal('7930.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 4, 15),
#   'C_PRC': Decimal('7850.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 4, 16),
#   'C_PRC': Decimal('7870.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 4, 17),
#   'C_PRC': Decimal('7880.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 4, 18),
#   'C_PRC': Decimal('7630.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 4, 19),
#   'C_PRC': Decimal('7810.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 4, 22),
#   'C_PRC': Decimal('8010.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 4, 23),
#   'C_PRC': Decimal('7850.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 4, 24),
#   'C_PRC': Decimal('7730.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 4, 25),
#   'C_PRC': Decimal('7830.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 4, 26),
#   'C_PRC': Decimal('7580.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 4, 29),
#   'C_PRC': Decimal('7620.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 4, 30),
#   'C_PRC': Decimal('8050.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 5, 2),
#   'C_PRC': Decimal('8020.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 5, 3),
#   'C_PRC': Decimal('8050.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 5, 7),
#   'C_PRC': Decimal('7940.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 5, 8),
#   'C_PRC': Decimal('7830.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 5, 9),
#   'C_PRC': Decimal('7580.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 5, 10),
#   'C_PRC': Decimal('7420.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 5, 13),
#   'C_PRC': Decimal('7100.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 5, 14),
#   'C_PRC': Decimal('7090.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 5, 15),
#   'C_PRC': Decimal('7240.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 5, 16),
#   'C_PRC': Decimal('7140.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 5, 17),
#   'C_PRC': Decimal('7000.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 5, 20),
#   'C_PRC': Decimal('6790.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 5, 21),
#   'C_PRC': Decimal('6850.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 5, 22),
#   'C_PRC': Decimal('6950.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 5, 23),
#   'C_PRC': Decimal('6840.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 5, 24),
#   'C_PRC': Decimal('6740.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 5, 27),
#   'C_PRC': Decimal('6720.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 5, 28),
#   'C_PRC': Decimal('7010.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 5, 29),
#   'C_PRC': Decimal('6840.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 5, 30),
#   'C_PRC': Decimal('6850.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 5, 31),
#   'C_PRC': Decimal('6910.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 6, 3),
#   'C_PRC': Decimal('6900.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 6, 4),
#   'C_PRC': Decimal('6970.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 6, 5),
#   'C_PRC': Decimal('6950.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 6, 7),
#   'C_PRC': Decimal('7040.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 6, 10),
#   'C_PRC': Decimal('7100.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 6, 11),
#   'C_PRC': Decimal('7270.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 6, 12),
#   'C_PRC': Decimal('7190.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 6, 13),
#   'C_PRC': Decimal('7270.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 6, 14),
#   'C_PRC': Decimal('7250.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 6, 17),
#   'C_PRC': Decimal('7100.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 6, 18),
#   'C_PRC': Decimal('7110.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 6, 19),
#   'C_PRC': Decimal('7090.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 6, 20),
#   'C_PRC': Decimal('7220.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 6, 21),
#   'C_PRC': Decimal('7110.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 6, 24),
#   'C_PRC': Decimal('7100.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 6, 25),
#   'C_PRC': Decimal('6980.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 6, 26),
#   'C_PRC': Decimal('7000.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 6, 27),
#   'C_PRC': Decimal('6870.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 6, 28),
#   'C_PRC': Decimal('6720.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 7, 1),
#   'C_PRC': Decimal('6870.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 7, 2),
#   'C_PRC': Decimal('6920.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 7, 3),
#   'C_PRC': Decimal('6800.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 7, 4),
#   'C_PRC': Decimal('6690.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 7, 5),
#   'C_PRC': Decimal('6740.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 7, 8),
#   'C_PRC': Decimal('6440.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 7, 9),
#   'C_PRC': Decimal('6210.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 7, 10),
#   'C_PRC': Decimal('6300.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 7, 11),
#   'C_PRC': Decimal('6390.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 7, 12),
#   'C_PRC': Decimal('6450.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 7, 15),
#   'C_PRC': Decimal('6350.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 7, 16),
#   'C_PRC': Decimal('6400.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 7, 17),
#   'C_PRC': Decimal('6440.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 7, 18),
#   'C_PRC': Decimal('6420.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 7, 19),
#   'C_PRC': Decimal('6510.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 7, 22),
#   'C_PRC': Decimal('6500.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 7, 23),
#   'C_PRC': Decimal('6420.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 7, 24),
#   'C_PRC': Decimal('6420.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 7, 25),
#   'C_PRC': Decimal('6450.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 7, 26),
#   'C_PRC': Decimal('6410.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 7, 29),
#   'C_PRC': Decimal('6000.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 7, 30),
#   'C_PRC': Decimal('6000.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 7, 31),
#   'C_PRC': Decimal('6180.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 8, 1),
#   'C_PRC': Decimal('6250.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 8, 2),
#   'C_PRC': Decimal('6120.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 8, 5),
#   'C_PRC': Decimal('5420.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 8, 6),
#   'C_PRC': Decimal('5020.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 8, 7),
#   'C_PRC': Decimal('5240.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 8, 8),
#   'C_PRC': Decimal('5440.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 8, 9),
#   'C_PRC': Decimal('5480.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 8, 12),
#   'C_PRC': Decimal('5550.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 8, 13),
#   'C_PRC': Decimal('5550.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 8, 14),
#   'C_PRC': Decimal('5520.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 8, 16),
#   'C_PRC': Decimal('5430.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 8, 19),
#   'C_PRC': Decimal('5430.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 8, 20),
#   'C_PRC': Decimal('5630.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 8, 21),
#   'C_PRC': Decimal('5750.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 8, 22),
#   'C_PRC': Decimal('5730.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 8, 23),
#   'C_PRC': Decimal('5670.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 8, 26),
#   'C_PRC': Decimal('5380.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 8, 27),
#   'C_PRC': Decimal('5400.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 8, 28),
#   'C_PRC': Decimal('5600.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 8, 29),
#   'C_PRC': Decimal('5710.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 8, 30),
#   'C_PRC': Decimal('5880.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 9, 2),
#   'C_PRC': Decimal('5900.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 9, 3),
#   'C_PRC': Decimal('5990.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 9, 4),
#   'C_PRC': Decimal('6070.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 9, 5),
#   'C_PRC': Decimal('6050.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 9, 6),
#   'C_PRC': Decimal('6070.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 9, 9),
#   'C_PRC': Decimal('5980.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 9, 10),
#   'C_PRC': Decimal('6020.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 9, 11),
#   'C_PRC': Decimal('6040.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 9, 16),
#   'C_PRC': Decimal('6110.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 9, 17),
#   'C_PRC': Decimal('6180.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 9, 18),
#   'C_PRC': Decimal('6140.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 9, 19),
#   'C_PRC': Decimal('6100.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 9, 20),
#   'C_PRC': Decimal('6090.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 9, 23),
#   'C_PRC': Decimal('6050.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 9, 24),
#   'C_PRC': Decimal('6130.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 9, 25),
#   'C_PRC': Decimal('5940.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 9, 26),
#   'C_PRC': Decimal('6010.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 9, 27),
#   'C_PRC': Decimal('6180.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 9, 30),
#   'C_PRC': Decimal('6230.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 10, 1),
#   'C_PRC': Decimal('6410.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 10, 2),
#   'C_PRC': Decimal('6210.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 10, 4),
#   'C_PRC': Decimal('6080.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 10, 7),
#   'C_PRC': Decimal('6260.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 10, 8),
#   'C_PRC': Decimal('6130.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 10, 10),
#   'C_PRC': Decimal('6120.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 10, 11),
#   'C_PRC': Decimal('6210.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 10, 14),
#   'C_PRC': Decimal('6190.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 10, 15),
#   'C_PRC': Decimal('6340.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 10, 16),
#   'C_PRC': Decimal('6360.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 10, 17),
#   'C_PRC': Decimal('6250.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 10, 18),
#   'C_PRC': Decimal('6200.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 10, 21),
#   'C_PRC': Decimal('6120.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 10, 22),
#   'C_PRC': Decimal('6080.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 10, 23),
#   'C_PRC': Decimal('6480.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 10, 24),
#   'C_PRC': Decimal('6190.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 10, 25),
#   'C_PRC': Decimal('6140.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 10, 28),
#   'C_PRC': Decimal('6430.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 10, 29),
#   'C_PRC': Decimal('6490.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 10, 30),
#   'C_PRC': Decimal('6410.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 10, 31),
#   'C_PRC': Decimal('6580.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 11, 1),
#   'C_PRC': Decimal('6760.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 11, 4),
#   'C_PRC': Decimal('7170.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 11, 5),
#   'C_PRC': Decimal('8050.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 11, 6),
#   'C_PRC': Decimal('7610.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 11, 7),
#   'C_PRC': Decimal('7330.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 11, 8),
#   'C_PRC': Decimal('7030.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 11, 11),
#   'C_PRC': Decimal('7150.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 11, 12),
#   'C_PRC': Decimal('6950.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 11, 13),
#   'C_PRC': Decimal('7210.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 11, 14),
#   'C_PRC': Decimal('6960.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 11, 15),
#   'C_PRC': Decimal('6970.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 11, 18),
#   'C_PRC': Decimal('6980.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 11, 19),
#   'C_PRC': Decimal('6700.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 11, 20),
#   'C_PRC': Decimal('6570.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 11, 21),
#   'C_PRC': Decimal('6440.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 11, 22),
#   'C_PRC': Decimal('6430.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 11, 25),
#   'C_PRC': Decimal('6570.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 11, 26),
#   'C_PRC': Decimal('6640.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 11, 27),
#   'C_PRC': Decimal('6690.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 11, 28),
#   'C_PRC': Decimal('6780.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 11, 29),
#   'C_PRC': Decimal('6600.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 12, 2),
#   'C_PRC': Decimal('6540.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 12, 3),
#   'C_PRC': Decimal('6660.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 12, 4),
#   'C_PRC': Decimal('6660.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 12, 5),
#   'C_PRC': Decimal('6650.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 12, 6),
#   'C_PRC': Decimal('6960.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 12, 9),
#   'C_PRC': Decimal('6920.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 12, 10),
#   'C_PRC': Decimal('6990.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 12, 11),
#   'C_PRC': Decimal('6870.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 12, 12),
#   'C_PRC': Decimal('6850.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 12, 13),
#   'C_PRC': Decimal('6850.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 12, 16),
#   'C_PRC': Decimal('6950.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 12, 17),
#   'C_PRC': Decimal('6870.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 12, 18),
#   'C_PRC': Decimal('6800.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 12, 19),
#   'C_PRC': Decimal('6870.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 12, 20),
#   'C_PRC': Decimal('6830.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 12, 23),
#   'C_PRC': Decimal('6820.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 12, 24),
#   'C_PRC': Decimal('6720.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 12, 26),
#   'C_PRC': Decimal('6740.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 12, 27),
#   'C_PRC': Decimal('6970.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2019, 12, 30),
#   'C_PRC': Decimal('7240.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 1, 2),
#   'C_PRC': Decimal('7320.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 1, 3),
#   'C_PRC': Decimal('7230.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 1, 6),
#   'C_PRC': Decimal('6950.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 1, 7),
#   'C_PRC': Decimal('7250.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 1, 8),
#   'C_PRC': Decimal('6780.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 1, 9),
#   'C_PRC': Decimal('6920.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 1, 10),
#   'C_PRC': Decimal('7040.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 1, 13),
#   'C_PRC': Decimal('6990.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 1, 14),
#   'C_PRC': Decimal('6920.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 1, 15),
#   'C_PRC': Decimal('6940.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 1, 16),
#   'C_PRC': Decimal('6920.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 1, 17),
#   'C_PRC': Decimal('6990.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 1, 20),
#   'C_PRC': Decimal('7140.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 1, 21),
#   'C_PRC': Decimal('7210.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 1, 22),
#   'C_PRC': Decimal('7380.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 1, 23),
#   'C_PRC': Decimal('7600.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 1, 28),
#   'C_PRC': Decimal('7710.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 1, 29),
#   'C_PRC': Decimal('7130.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 1, 30),
#   'C_PRC': Decimal('7010.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 1, 31),
#   'C_PRC': Decimal('6630.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 2, 3),
#   'C_PRC': Decimal('6470.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 2, 4),
#   'C_PRC': Decimal('6580.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 2, 5),
#   'C_PRC': Decimal('8550.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 2, 6),
#   'C_PRC': Decimal('9970.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 2, 7),
#   'C_PRC': Decimal('8800.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 2, 10),
#   'C_PRC': Decimal('7880.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 2, 11),
#   'C_PRC': Decimal('7510.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 2, 12),
#   'C_PRC': Decimal('6940.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 2, 13),
#   'C_PRC': Decimal('6900.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 2, 14),
#   'C_PRC': Decimal('6900.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 2, 17),
#   'C_PRC': Decimal('7160.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 2, 18),
#   'C_PRC': Decimal('8230.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 2, 19),
#   'C_PRC': Decimal('9160.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 2, 20),
#   'C_PRC': Decimal('8140.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 2, 21),
#   'C_PRC': Decimal('9000.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 2, 24),
#   'C_PRC': Decimal('8850.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 2, 25),
#   'C_PRC': Decimal('7850.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 2, 26),
#   'C_PRC': Decimal('7910.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 2, 27),
#   'C_PRC': Decimal('7510.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 2, 28),
#   'C_PRC': Decimal('7360.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 3, 2),
#   'C_PRC': Decimal('7230.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 3, 3),
#   'C_PRC': Decimal('8670.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 3, 4),
#   'C_PRC': Decimal('8030.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 3, 5),
#   'C_PRC': Decimal('8070.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 3, 6),
#   'C_PRC': Decimal('8130.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 3, 9),
#   'C_PRC': Decimal('8220.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 3, 10),
#   'C_PRC': Decimal('7860.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 3, 11),
#   'C_PRC': Decimal('8060.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 3, 12),
#   'C_PRC': Decimal('8410.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 3, 13),
#   'C_PRC': Decimal('7950.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 3, 16),
#   'C_PRC': Decimal('8020.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 3, 17),
#   'C_PRC': Decimal('7850.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 3, 18),
#   'C_PRC': Decimal('7800.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 3, 19),
#   'C_PRC': Decimal('6610.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 3, 20),
#   'C_PRC': Decimal('7880.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 3, 23),
#   'C_PRC': Decimal('8340.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 3, 24),
#   'C_PRC': Decimal('8550.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 3, 25),
#   'C_PRC': Decimal('9610.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 3, 26),
#   'C_PRC': Decimal('12450.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 3, 27),
#   'C_PRC': Decimal('13000.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 3, 30),
#   'C_PRC': Decimal('14750.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 3, 31),
#   'C_PRC': Decimal('14400.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 4, 1),
#   'C_PRC': Decimal('12150.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 4, 2),
#   'C_PRC': Decimal('11850.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 4, 3),
#   'C_PRC': Decimal('15400.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 4, 6),
#   'C_PRC': Decimal('20000.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 4, 8),
#   'C_PRC': Decimal('20450.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 4, 10),
#   'C_PRC': Decimal('23750.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 4, 13),
#   'C_PRC': Decimal('22000.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 4, 14),
#   'C_PRC': Decimal('19200.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 4, 16),
#   'C_PRC': Decimal('15800.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 4, 17),
#   'C_PRC': Decimal('16250.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 4, 20),
#   'C_PRC': Decimal('18950.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 4, 21),
#   'C_PRC': Decimal('18350.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 4, 22),
#   'C_PRC': Decimal('18700.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 4, 23),
#   'C_PRC': Decimal('18750.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 4, 24),
#   'C_PRC': Decimal('18200.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 4, 27),
#   'C_PRC': Decimal('18050.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 4, 28),
#   'C_PRC': Decimal('17050.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 4, 29),
#   'C_PRC': Decimal('16700.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 5, 4),
#   'C_PRC': Decimal('19250.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 5, 6),
#   'C_PRC': Decimal('19100.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 5, 7),
#   'C_PRC': Decimal('18950.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 5, 8),
#   'C_PRC': Decimal('19050.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 5, 11),
#   'C_PRC': Decimal('19250.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 5, 12),
#   'C_PRC': Decimal('19900.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 5, 13),
#   'C_PRC': Decimal('20100.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 5, 14),
#   'C_PRC': Decimal('22300.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 5, 15),
#   'C_PRC': Decimal('20300.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 5, 18),
#   'C_PRC': Decimal('19700.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 5, 19),
#   'C_PRC': Decimal('20150.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 5, 20),
#   'C_PRC': Decimal('20100.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 5, 21),
#   'C_PRC': Decimal('19950.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 5, 22),
#   'C_PRC': Decimal('20000.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 5, 25),
#   'C_PRC': Decimal('20200.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 5, 26),
#   'C_PRC': Decimal('20650.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 5, 27),
#   'C_PRC': Decimal('20600.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 5, 28),
#   'C_PRC': Decimal('20450.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 5, 29),
#   'C_PRC': Decimal('21700.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 6, 1),
#   'C_PRC': Decimal('21250.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 6, 2),
#   'C_PRC': Decimal('20600.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 6, 3),
#   'C_PRC': Decimal('19900.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 6, 4),
#   'C_PRC': Decimal('19950.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 6, 5),
#   'C_PRC': Decimal('20450.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 6, 8),
#   'C_PRC': Decimal('20950.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 6, 9),
#   'C_PRC': Decimal('27200.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 6, 10),
#   'C_PRC': Decimal('29450.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 6, 11),
#   'C_PRC': Decimal('31050.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 6, 12),
#   'C_PRC': Decimal('30500.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 6, 15),
#   'C_PRC': Decimal('34300.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 6, 16),
#   'C_PRC': Decimal('31700.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 6, 17),
#   'C_PRC': Decimal('29250.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 6, 18),
#   'C_PRC': Decimal('30750.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 6, 19),
#   'C_PRC': Decimal('30150.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 6, 22),
#   'C_PRC': Decimal('30200.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 6, 23),
#   'C_PRC': Decimal('30000.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 6, 24),
#   'C_PRC': Decimal('29000.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 6, 25),
#   'C_PRC': Decimal('29000.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 6, 26),
#   'C_PRC': Decimal('28950.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 6, 29),
#   'C_PRC': Decimal('28700.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 6, 30),
#   'C_PRC': Decimal('30200.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 7, 1),
#   'C_PRC': Decimal('29250.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 7, 2),
#   'C_PRC': Decimal('29300.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 7, 3),
#   'C_PRC': Decimal('29550.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 7, 6),
#   'C_PRC': Decimal('31050.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 7, 7),
#   'C_PRC': Decimal('37950.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 7, 8),
#   'C_PRC': Decimal('39400.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 7, 9),
#   'C_PRC': Decimal('41150.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 7, 10),
#   'C_PRC': Decimal('48650.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 7, 13),
#   'C_PRC': Decimal('60300.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 7, 14),
#   'C_PRC': Decimal('62500.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 7, 15),
#   'C_PRC': Decimal('62600.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 7, 16),
#   'C_PRC': Decimal('63100.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 7, 17),
#   'C_PRC': Decimal('73000.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 7, 20),
#   'C_PRC': Decimal('94900.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 7, 22),
#   'C_PRC': Decimal('123000.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 7, 24),
#   'C_PRC': Decimal('105000.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 7, 27),
#   'C_PRC': Decimal('73500.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 7, 28),
#   'C_PRC': Decimal('71600.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 7, 29),
#   'C_PRC': Decimal('75000.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 7, 30),
#   'C_PRC': Decimal('86000.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 7, 31),
#   'C_PRC': Decimal('69000.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 8, 3),
#   'C_PRC': Decimal('73500.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 8, 4),
#   'C_PRC': Decimal('75000.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 8, 5),
#   'C_PRC': Decimal('78700.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 8, 6),
#   'C_PRC': Decimal('77400.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 8, 7),
#   'C_PRC': Decimal('76100.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 8, 10),
#   'C_PRC': Decimal('75600.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 8, 11),
#   'C_PRC': Decimal('76900.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 8, 12),
#   'C_PRC': Decimal('71800.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 8, 13),
#   'C_PRC': Decimal('75100.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 8, 14),
#   'C_PRC': Decimal('75100.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 8, 18),
#   'C_PRC': Decimal('83500.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 8, 19),
#   'C_PRC': Decimal('83500.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 8, 20),
#   'C_PRC': Decimal('93200.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 8, 21),
#   'C_PRC': Decimal('91000.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 8, 24),
#   'C_PRC': Decimal('100500.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 8, 25),
#   'C_PRC': Decimal('114000.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 8, 26),
#   'C_PRC': Decimal('113000.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 8, 27),
#   'C_PRC': Decimal('111500.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 8, 28),
#   'C_PRC': Decimal('111000.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 8, 31),
#   'C_PRC': Decimal('136500.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 9, 1),
#   'C_PRC': Decimal('147000.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 9, 2),
#   'C_PRC': Decimal('158000.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 9, 3),
#   'C_PRC': Decimal('156500.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 9, 4),
#   'C_PRC': Decimal('146000.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 9, 7),
#   'C_PRC': Decimal('148500.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 9, 8),
#   'C_PRC': Decimal('140000.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 9, 9),
#   'C_PRC': Decimal('139500.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 9, 10),
#   'C_PRC': Decimal('141000.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 9, 11),
#   'C_PRC': Decimal('153500.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 9, 14),
#   'C_PRC': Decimal('146500.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 9, 15),
#   'C_PRC': Decimal('146500.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 9, 16),
#   'C_PRC': Decimal('154000.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 9, 17),
#   'C_PRC': Decimal('152500.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 9, 18),
#   'C_PRC': Decimal('198000.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 9, 21),
#   'C_PRC': Decimal('193500.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 9, 22),
#   'C_PRC': Decimal('166000.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 9, 23),
#   'C_PRC': Decimal('165000.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 9, 24),
#   'C_PRC': Decimal('150000.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 9, 25),
#   'C_PRC': Decimal('136000.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 9, 28),
#   'C_PRC': Decimal('133500.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 9, 29),
#   'C_PRC': Decimal('126500.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 10, 5),
#   'C_PRC': Decimal('127000.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 10, 6),
#   'C_PRC': Decimal('134000.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 10, 7),
#   'C_PRC': Decimal('135500.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 10, 8),
#   'C_PRC': Decimal('140000.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 10, 12),
#   'C_PRC': Decimal('133500.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 10, 13),
#   'C_PRC': Decimal('122500.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 10, 14),
#   'C_PRC': Decimal('126000.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 10, 15),
#   'C_PRC': Decimal('125000.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 10, 16),
#   'C_PRC': Decimal('119000.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 10, 19),
#   'C_PRC': Decimal('128500.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 10, 20),
#   'C_PRC': Decimal('125500.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 10, 21),
#   'C_PRC': Decimal('135500.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 10, 22),
#   'C_PRC': Decimal('136500.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 10, 23),
#   'C_PRC': Decimal('139000.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 10, 26),
#   'C_PRC': Decimal('136500.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 10, 27),
#   'C_PRC': Decimal('127000.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 10, 28),
#   'C_PRC': Decimal('131000.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 10, 29),
#   'C_PRC': Decimal('130000.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 10, 30),
#   'C_PRC': Decimal('125500.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 11, 2),
#   'C_PRC': Decimal('126000.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 11, 3),
#   'C_PRC': Decimal('134500.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 11, 4),
#   'C_PRC': Decimal('134500.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 11, 5),
#   'C_PRC': Decimal('135000.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 11, 6),
#   'C_PRC': Decimal('133000.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 11, 9),
#   'C_PRC': Decimal('134000.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 11, 10),
#   'C_PRC': Decimal('128500.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 11, 11),
#   'C_PRC': Decimal('123500.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 11, 12),
#   'C_PRC': Decimal('105000.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 11, 13),
#   'C_PRC': Decimal('126000.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 11, 16),
#   'C_PRC': Decimal('130500.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 11, 17),
#   'C_PRC': Decimal('126000.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 11, 18),
#   'C_PRC': Decimal('120500.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 11, 19),
#   'C_PRC': Decimal('123000.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 11, 20),
#   'C_PRC': Decimal('123000.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 11, 23),
#   'C_PRC': Decimal('119500.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 11, 24),
#   'C_PRC': Decimal('120500.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 11, 25),
#   'C_PRC': Decimal('119000.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 11, 26),
#   'C_PRC': Decimal('128500.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 11, 27),
#   'C_PRC': Decimal('128500.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 11, 30),
#   'C_PRC': Decimal('132000.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 12, 1),
#   'C_PRC': Decimal('144000.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 12, 2),
#   'C_PRC': Decimal('177500.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 12, 3),
#   'C_PRC': Decimal('179000.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 12, 4),
#   'C_PRC': Decimal('188500.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 12, 7),
#   'C_PRC': Decimal('188500.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 12, 8),
#   'C_PRC': Decimal('188500.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 12, 9),
#   'C_PRC': Decimal('191000.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 12, 10),
#   'C_PRC': Decimal('190500.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 12, 11),
#   'C_PRC': Decimal('157000.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 12, 14),
#   'C_PRC': Decimal('159000.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 12, 15),
#   'C_PRC': Decimal('147000.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 12, 16),
#   'C_PRC': Decimal('146000.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 12, 17),
#   'C_PRC': Decimal('150500.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 12, 18),
#   'C_PRC': Decimal('149500.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 12, 21),
#   'C_PRC': Decimal('122500.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 12, 22),
#   'C_PRC': Decimal('120500.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 12, 23),
#   'C_PRC': Decimal('113500.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 12, 24),
#   'C_PRC': Decimal('119000.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 12, 28),
#   'C_PRC': Decimal('112500.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 12, 29),
#   'C_PRC': Decimal('120500.000')},
#  {'STK_CD': '019170',
#   'DT': datetime.date(2020, 12, 30),
#   'C_PRC': Decimal('124000.000')}]

# %%
# result를 DataFrame으로 변환
df = pd.DataFrame(result)

# %%
df
# Out:
#      STK_CD          DT       C_PRC
# 0    019170  2019-01-02    6260.000
# 1    019170  2019-01-03    6170.000
# 2    019170  2019-01-04    6840.000
# 3    019170  2019-01-07    7410.000
# 4    019170  2019-01-08    7200.000
# ..      ...         ...         ...
# 485  019170  2020-12-23  113500.000
# 486  019170  2020-12-24  119000.000
# 487  019170  2020-12-28  112500.000
# 488  019170  2020-12-29  120500.000
# 489  019170  2020-12-30  124000.000
#
# [490 rows x 3 columns]

# %%
#조회한 컬럼 정보 조회
cursor.description
# Out:
# (('STK_CD', 253, None, 40, 40, 0, False),
#  ('DT', 10, None, 10, 10, 0, False),
#  ('C_PRC', 246, None, 20, 20, 3, True))

# %%
#조회한 컬럼의 정보를 desc에 저장
desc = cursor.description

# %%
desc
# Out:
# (('STK_CD', 253, None, 40, 40, 0, False),
#  ('DT', 10, None, 10, 10, 0, False),
#  ('C_PRC', 246, None, 20, 20, 3, True))

# %%
#리스트의 행 열 방향을 반대로 바꿈
list( zip(*desc) )
# Out:
# [('STK_CD', 'DT', 'C_PRC'),
#  (253, 10, 246),
#  (None, None, None),
#  (40, 10, 20),
#  (40, 10, 20),
#  (0, 0, 3),
#  (False, False, True)]

# %%
#리스트의 0번째 열 리턴 => 조회한 컬럼 이름
list( zip(*desc) )[0]
# Out:
# ('STK_CD', 'DT', 'C_PRC')

# %%
#조회한 컬럼 이름을 column_name 에 대입
column_name = list( zip(*desc) )[0]

# %%
column_name
# Out:
# ('STK_CD', 'DT', 'C_PRC')

# %%
# for element in column_name : column_name에서 컬럼 이름 1개를 element에 대입
#element.upper() : 컬럼 이름 1개가 저장된 element를 대문자로 변환해서 리턴

[element.upper() for element in column_name]
# Out:
# ['STK_CD', 'DT', 'C_PRC']

# %%
# for element in column_name : column_name에서 컬럼 이름 1개를 element에 대입
#element.upper() : 컬럼 이름 1개가 저장된 element를 대문자로 변환해서 리턴
#대문자로 변환한 컬럼 이름을 column_name에 대입

column_name = [element.upper() for element in column_name]

# %%
column_name
# Out:
# ['STK_CD', 'DT', 'C_PRC']

# %%
#re.sub() : 특정 문자를 찾아서 삭제
#\S : 문자열
#\. : .
# .앞의 문자열 찾아서 삭제

# T3.FIN_ITM_VAL -> FIN_ITM_VAL 으로 변환

re.sub('\S*\.',"","T3.FIN_ITM_VAL" )
# Out:
# 'FIN_ITM_VAL'

# %%
#re.sub() : 특정 문자를 찾아서 삭제
#\S : 문자열
#\. : .
# .앞의 문자열 찾아서 삭제

# 컬럼 이름에 . 앞의 문자열 삭제

column_name = [re.sub('\S*\.',"",element)  for element in column_name]

# %%
column_name
# Out:
# ['STK_CD', 'DT', 'C_PRC']

# %%
df.columns = column_name

# %%
df
# Out:
#      STK_CD          DT       C_PRC
# 0    019170  2019-01-02    6260.000
# 1    019170  2019-01-03    6170.000
# 2    019170  2019-01-04    6840.000
# 3    019170  2019-01-07    7410.000
# 4    019170  2019-01-08    7200.000
# ..      ...         ...         ...
# 485  019170  2020-12-23  113500.000
# 486  019170  2020-12-24  119000.000
# 487  019170  2020-12-28  112500.000
# 488  019170  2020-12-29  120500.000
# 489  019170  2020-12-30  124000.000
#
# [490 rows x 3 columns]

# %%
# df의 컬럼 타입 조회
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 490 entries, 0 to 489
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   STK_CD  490 non-null    object
#  1   DT      490 non-null    object
#  2   C_PRC   490 non-null    object
# dtypes: object(3)
# memory usage: 11.6+ KB

# %%
df
# Out:
#      STK_CD          DT       C_PRC
# 0    019170  2019-01-02    6260.000
# 1    019170  2019-01-03    6170.000
# 2    019170  2019-01-04    6840.000
# 3    019170  2019-01-07    7410.000
# 4    019170  2019-01-08    7200.000
# ..      ...         ...         ...
# 485  019170  2020-12-23  113500.000
# 486  019170  2020-12-24  119000.000
# 487  019170  2020-12-28  112500.000
# 488  019170  2020-12-29  120500.000
# 489  019170  2020-12-30  124000.000
#
# [490 rows x 3 columns]

# %%
# DT 컬럼의 타입을 날짜와 시간으로 변환
df["DT"] = pd.to_datetime (df["DT"])

# %%
# C_PRC 컬럼의 타입을 정수로 변환
df.loc[: , "C_PRC" ] = df.loc[: , "C_PRC" ].astype("int64")

# %%
# df의 컬럼 타입 조회
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 490 entries, 0 to 489
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   STK_CD  490 non-null    object
#  1   DT      490 non-null    datetime64[ns]
#  2   C_PRC   490 non-null    object
# dtypes: datetime64[ns](1), object(2)
# memory usage: 11.6+ KB

# %% [markdown]
# ## 분산과 표준편차
#
# * [Pandas Bollinger Bands 예제](https://pandas.pydata.org/docs/user_guide/visualization.html#plotting-directly-with-matplotlib)
#
# * 표준편차
#     * 표준 편차(標準 偏差, 영어: standard deviation)는 자료의 산포도를 나타내는 수치로, 분산의 양의 제곱근으로 정의된다. 표준편차가 작을수록 평균값에서 변량들의 거리가 가깝다. 통계학과 확률에서 주로 확률의 분포, 확률변수 혹은 측정된 인구나 중복집합에 적용된다. 관례에 따라 모집단은 그리스문자로 표본은 영어 알파벳으로 표기하는데, 모집단의 표준편차는 σ(시그마)로, 표본의 표준편차는 s(에스)로 나타낸다
#     * 편차(deviation)는 관측값에서 평균 또는 중앙값을 뺀 것이다.
#     * 분산(variance)은 관측값에서 평균을 뺀 값을 제곱하고, 그것을 모두 더한 후 전체 개수로 나눠서 구한다. 즉, 차이값의 제곱의 평균이다. 관측값에서 평균을 뺀 값인 편차를 모두 더하면 0이 나오므로 제곱해서 더한다.
#     * 표준 편차(standard deviation)는 분산을 제곱근한 것이다. 편차들(deviations)의 제곱합(SS, sum of square)에서 얻어진 값의 평균치인 분산의 성질로 부터 다시 제곱근해서 원래 단위로 만들어줌으로써 얻게된다.
#
# * 출처 : [표준 편차 - 위키백과, 우리 모두의 백과사전](https://ko.wikipedia.org/wiki/%ED%91%9C%EC%A4%80_%ED%8E%B8%EC%B0%A8)
#
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/8/8c/Standard_deviation_diagram.svg/700px-Standard_deviation_diagram.svg.png" width="500">
#
#
# * 통계학에서 68-95-99.7 규칙(영어: 68-95-99.7 rule)은 정규 분포를 나타내는 규칙으로, 경험적인 규칙(empirical rule)이라고도 한다. 3시그마 규칙(three-sigma rule)이라고도 하는데 이 때는 평균에서 양쪽으로 3표준편차의 범위에 거의 모든 값들(99.7%)이 들어간다는 것을 나타낸다.
#
# * 약 68%의 값들이 평균에서 양쪽으로 1 표준편차 범위(μ±σ)에 존재한다.
# * **약 95%의 값들이 평균에서 양쪽으로 2 표준편차 범위(μ±2σ)에 존재한다.**
# * 거의 모든 값들(실제로는 99.7%)이 평균에서 양쪽으로 3표준편차 범위(μ±3σ)에 존재한다.
#
# * 출처 : [68-95-99.7 규칙 - 위키백과, 우리 모두의 백과사전](https://ko.wikipedia.org/wiki/68-95-99.7_%EA%B7%9C%EC%B9%99)

# %%
# 종가의 기술 통계 값
df["C_PRC"].describe()
# Out:
# count      490
# unique     322
# top       6920
# freq         5
# Name: C_PRC, dtype: int64

# %%
# 종가 분산
df["C_PRC"].var()
# Out:
# 2641273206.210509

# %%
# 표준편차 == 분산에 루트 
# np.sqrt() : 루트 계산
# 분산에 루트를 계산하면 표준편차
np.sqrt(df["C_PRC"].var())
# Out:
# 51393.318692321365

# %%
# 분산에 0.5 승을 해도 표준편차
df["C_PRC"].var() ** 0.5
# Out:
# 51393.318692321365

# %%
# 종가의 표준편차
df["C_PRC"].std()
# Out:
# 51393.318692321365

# %%
df
# Out:
#      STK_CD         DT   C_PRC
# 0    019170 2019-01-02    6260
# 1    019170 2019-01-03    6170
# 2    019170 2019-01-04    6840
# 3    019170 2019-01-07    7410
# 4    019170 2019-01-08    7200
# ..      ...        ...     ...
# 485  019170 2020-12-23  113500
# 486  019170 2020-12-24  119000
# 487  019170 2020-12-28  112500
# 488  019170 2020-12-29  120500
# 489  019170 2020-12-30  124000
#
# [490 rows x 3 columns]

# %% [markdown]
# ## 20일간 종가 이동평균과 표준편차

# %% [markdown]
# ** 이동평균 : https://www.cmegroup.com/ko/education/learn-about-trading/courses/technical-analysis/understanding-moving-averages.html#

# %%
# 20일간 종가의 이동평균

# rolling(20).mean() : 20일간의 이동 평균을 계산하는 함수
df["MA20"] = df["C_PRC"].rolling(20).mean()

# %%
df.head(50)
# Out:
#     STK_CD         DT C_PRC    MA20
# 0   019170 2019-01-02  6260     NaN
# 1   019170 2019-01-03  6170     NaN
# 2   019170 2019-01-04  6840     NaN
# 3   019170 2019-01-07  7410     NaN
# 4   019170 2019-01-08  7200     NaN
# 5   019170 2019-01-09  7180     NaN
# 6   019170 2019-01-10  7110     NaN
# 7   019170 2019-01-11  6960     NaN
# 8   019170 2019-01-14  7020     NaN
# 9   019170 2019-01-15  7130     NaN
# 10  019170 2019-01-16  6930     NaN
# 11  019170 2019-01-17  6740     NaN
# 12  019170 2019-01-18  7040     NaN
# 13  019170 2019-01-21  7030     NaN
# 14  019170 2019-01-22  7210     NaN
# 15  019170 2019-01-23  7200     NaN
# 16  019170 2019-01-24  7320     NaN
# 17  019170 2019-01-25  7180     NaN
# 18  019170 2019-01-28  7390     NaN
# 19  019170 2019-01-29  7240  7028.0
# 20  019170 2019-01-30  7090  7069.5
# 21  019170 2019-01-31  7250  7123.5
# 22  019170 2019-02-01  7160  7139.5
# 23  019170 2019-02-07  7520  7145.0
# 24  019170 2019-02-08  7690  7169.5
# 25  019170 2019-02-11  8010  7211.0
# 26  019170 2019-02-12  8050  7258.0
# 27  019170 2019-02-13  8250  7322.5
# 28  019170 2019-02-14  8180  7380.5
# 29  019170 2019-02-15  8060  7427.0
# 30  019170 2019-02-18  8340  7497.5
# 31  019170 2019-02-19  8220  7571.5
# 32  019170 2019-02-20  8070  7623.0
# 33  019170 2019-02-21  8040  7673.5
# 34  019170 2019-02-22  8100  7718.0
# 35  019170 2019-02-25  8030  7759.5
# 36  019170 2019-02-26  8010  7794.0
# 37  019170 2019-02-27  8200  7845.0
# 38  019170 2019-02-28  7920  7871.5
# 39  019170 2019-03-04  8630  7941.0
# 40  019170 2019-03-05  8470  8010.0
# 41  019170 2019-03-06  8320  8063.5
# 42  019170 2019-03-07  8190  8115.0
# 43  019170 2019-03-08  8230  8150.5
# 44  019170 2019-03-11  8230  8177.5
# 45  019170 2019-03-12  8180  8186.0
# 46  019170 2019-03-13  8460  8206.5
# 47  019170 2019-03-14  8400  8214.0
# 48  019170 2019-03-15  8090  8209.5
# 49  019170 2019-03-18  7950  8204.0

# %%
# 20일간 주가의 표준편차
df["stddev"] = df["C_PRC"].rolling(20).std()

# %%
df.head(50)
# Out:
#     STK_CD         DT C_PRC    MA20      stddev
# 0   019170 2019-01-02  6260     NaN         NaN
# 1   019170 2019-01-03  6170     NaN         NaN
# 2   019170 2019-01-04  6840     NaN         NaN
# 3   019170 2019-01-07  7410     NaN         NaN
# 4   019170 2019-01-08  7200     NaN         NaN
# 5   019170 2019-01-09  7180     NaN         NaN
# 6   019170 2019-01-10  7110     NaN         NaN
# 7   019170 2019-01-11  6960     NaN         NaN
# 8   019170 2019-01-14  7020     NaN         NaN
# 9   019170 2019-01-15  7130     NaN         NaN
# 10  019170 2019-01-16  6930     NaN         NaN
# 11  019170 2019-01-17  6740     NaN         NaN
# 12  019170 2019-01-18  7040     NaN         NaN
# 13  019170 2019-01-21  7030     NaN         NaN
# 14  019170 2019-01-22  7210     NaN         NaN
# 15  019170 2019-01-23  7200     NaN         NaN
# 16  019170 2019-01-24  7320     NaN         NaN
# 17  019170 2019-01-25  7180     NaN         NaN
# 18  019170 2019-01-28  7390     NaN         NaN
# 19  019170 2019-01-29  7240  7028.0  326.183674
# 20  019170 2019-01-30  7090  7069.5  271.554492
# 21  019170 2019-01-31  7250  7123.5  172.635149
# 22  019170 2019-02-01  7160  7139.5  159.290367
# 23  019170 2019-02-07  7520  7145.0  170.618071
# 24  019170 2019-02-08  7690  7169.5  209.648202
# 25  019170 2019-02-11  8010  7211.0  281.628722
# 26  019170 2019-02-12  8050  7258.0  336.899173
# 27  019170 2019-02-13  8250  7322.5  395.273057
# 28  019170 2019-02-14  8180  7380.5  431.953640
# 29  019170 2019-02-15  8060  7427.0  453.107400
# 30  019170 2019-02-18  8340  7497.5  480.568468
# 31  019170 2019-02-19  8220  7571.5  471.651912
# 32  019170 2019-02-20  8070  7623.0  466.770540
# 33  019170 2019-02-21  8040  7673.5  453.689843
# 34  019170 2019-02-22  8100  7718.0  449.462837
# 35  019170 2019-02-25  8030  7759.5  437.269940
# 36  019170 2019-02-26  8010  7794.0  427.888328
# 37  019170 2019-02-27  8200  7845.0  411.320083
# 38  019170 2019-02-28  7920  7871.5  397.297118
# 39  019170 2019-03-04  8630  7941.0  402.556305
# 40  019170 2019-03-05  8470  8010.0  365.585327
# 41  019170 2019-03-06  8320  8063.5  324.495965
# 42  019170 2019-03-07  8190  8115.0  245.731989
# 43  019170 2019-03-08  8230  8150.5  202.782616
# 44  019170 2019-03-11  8230  8177.5  171.828403
# 45  019170 2019-03-12  8180  8186.0  167.250207
# 46  019170 2019-03-13  8460  8206.5  174.665846
# 47  019170 2019-03-14  8400  8214.0  179.777640
# 48  019170 2019-03-15  8090  8209.5  181.788628
# 49  019170 2019-03-18  7950  8204.0  188.104115

# %%
# 상위 밴드
# UpperB = 종가의 이동평균 + (표준편차 * 2)
df["UpperB"] = df["MA20"] + (df["stddev"] * 2)

# %%
# 하위밴드
# LowerB = 종가의 이동평균 - (표준편차 * 2)
df["LowerB"] = df["MA20"] - (df["stddev"] * 2)

# %%
df
# Out:
#      STK_CD         DT   C_PRC      MA20        stddev         UpperB
# 0    019170 2019-01-02    6260       NaN           NaN            NaN  \
# 1    019170 2019-01-03    6170       NaN           NaN            NaN
# 2    019170 2019-01-04    6840       NaN           NaN            NaN
# 3    019170 2019-01-07    7410       NaN           NaN            NaN
# 4    019170 2019-01-08    7200       NaN           NaN            NaN
# ..      ...        ...     ...       ...           ...            ...
# 485  019170 2020-12-23  113500  155100.0  26401.554978  207903.109956
# 486  019170 2020-12-24  119000  154625.0  26984.340001  208593.680001
# 487  019170 2020-12-28  112500  153825.0  28017.041337  209859.082673
# 488  019170 2020-12-29  120500  153250.0  28600.469264  210450.938527
# 489  019170 2020-12-30  124000  152250.0  29282.426920  210814.853840
#
#             LowerB
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# ..             ...
# 485  102296.890044
# 486  100656.319999
# 487   97790.917327
# 488   96049.061473
# 489   93685.146160
#
# [490 rows x 7 columns]

# %% [markdown]
# ## pyplot을 통한 볼린저 밴드 시각화

# %%
# pyplot을 통해 볼린저밴드를 시각화 합니다.

# 그래프의 크기 가로 30 세로 10
plt.figure(figsize=(30, 10))
# 상위 밴드 : 주식의 가격이 움직이는 밴드의 상위값 (빨강색으로 표시)
plt.plot(df.DT, df.UpperB, "r--")
# 실제 주식의 가격 (종가) : 검정색
plt.plot(df.DT, df.C_PRC, "k")
# 하위밴드 : 주식이 움직이는 가격이 움직이는 밴드의 하위값 (하위값)
plt.plot(df.DT, df.LowerB, "b--")

# 각 날짜의 df.LowerB(하위밴드) ~ df.UpperB (상위밴드) 사이를 색을 칠함
plt.fill_between(df.DT, df.LowerB, df.UpperB, alpha=0.2)

# %% [markdown]
# ## %밴드
# * %밴드를 통해 추세가 아닌 **주가의 상대적인 위치**를 파악할 수 있습니다.
# * 0 보다 작거나 1보다 큰 구간은 밴드의 범위를 벗어난 구간으로 볼 수 있습니다.

# %%
# PercentB = (종가 - 하위밴드) / (상위밴드 - 하위밴드)
df["PercentB"] = (df["C_PRC"] - df["LowerB"]) / (df["UpperB"] - df["LowerB"])

# %%
# 밴드 내에서 주가의 상대적인 위치를 시각화 합니다.
# 1보다 크면 밴드폭 상단을 돌파한 것이고
# 0보다 작으면 밴드폭 하단을 뚫고 내려간 것입니다.

# 그래프의 크기 가로 15 세로 5
plt.figure(figsize=(15, 5))
# 밴드내에서 주가의 상대 위치를 막대 그래프로 출력
plt.bar(df.DT, df["PercentB"])

# 1 지점에 선그림 (빨강색) -> 1보다 크면 밴드폭 상단을 돌파한 것이고
plt.axhline(1, c="r", lw=1)
# 0.5 지점에 선그림 (파랑색)
plt.axhline(0.5, c="b", lw=1)
# 0 지점에 선그림 (검정색) -> 0보다 작으면 밴드폭 하단을 뚫고 내려간 것입니다.
plt.axhline(0, c="k", lw=1)
